# %% [markdown]
# Data Handling and Analysis with Pandas

# %% [markdown]
# pandas is Python package
#
# Provides fast, flexible, and expressive data structures designed to make working with relational or labeled data.
#
# Open source data analysis and manipulation tool.
#
# Its is suited for
#
# Tabular data with heterogeneously-typed columns, as in an Excel spreadsheet
# Ordered and unordered (not necessarily fixed-frequency) time series data.
# Arbitrary matrix data (homogeneously typed or heterogeneous) with row and column labels
# Any other form of observational / statistical data sets.

# %% [markdown]
# Features
#
# • Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data.
#
# • Size mutability: columns can be inserted and deleted from DataFrame and higher dimensional objects.
#
# • Automatic and explicit data alignment.
#
# • Powerful, flexible group by functionality to perform split-apply-combine operations on data sets, for both ag- gregating and transforming data.
#
# • Make it easy to convert ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects.
#
# • Intelligent label-based slicing, fancy indexing, and subsetting of large data sets.
#
# • Intuitive merging and joining data sets.
#
# • Flexible reshaping and pivoting of data sets.
#
# • Hierarchical labeling of axes (possible to have multiple labels per tick).
#
# • Robust IO tools for loading data from flat files (CSV and delimited), Excel files, databases, and saving / loading data from the ultrafast HDF5 format.
#
# • Time series-specific functionality: date range generation and frequency conversion, moving window statistics, moving window linear regressions, date shifting and lagging, etc.
#
# Pandas handle Series (1D) and DataFrame (2D) datastructures

# %%
import pandas as pd
import numpy as np
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
s.isnull()
print(s)
s.fillna(0)
print(s)
s.interpolate()
print(s)
s.dropna()
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
n=pd.Series(['VIIT','VIT','VCACS','VU','VIM'])
n
# Out:
# 0     VIIT
# 1      VIT
# 2    VCACS
# 3       VU
# 4      VIM
# dtype: str

# %%
inst={'Name':['VIIT','VIT','VCACS','VU','VIM'],
      'Estd' :[2002,1984,2008,2017,2000]}
df=pd.DataFrame(inst)
#print(df)
df
# Out:
#     Name  Estd
# 0   VIIT  2002
# 1    VIT  1984
# 2  VCACS  2008
# 3     VU  2017
# 4    VIM  2000

# %%
i=pd.Series([2002,1984,2008,2017,2000])
inst={'Name':n,
      'Estd' :i}
ins=pd.DataFrame(inst)
ins
print(ins['Name'])
print(ins)
ins.index
# Out:
# 0     VIIT
# 1      VIT
# 2    VCACS
# 3       VU
# 4      VIM
# Name: Name, dtype: str
#     Name  Estd
# 0   VIIT  2002
# 1    VIT  1984
# 2  VCACS  2008
# 3     VU  2017
# 4    VIM  2000
# RangeIndex(start=0, stop=5, step=1)

# %%
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)
df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
# using dropna() function
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
import pandas as pd

# dictionary of lists
Pro = {'Name':['Ramesh', 'Shreyas', 'Rohit', 'Rahul'],
        'BTech': ['Comp', 'ETC', 'Mech', 'Civil'],
        'CGPA':[9, 8.5, 8, 8.25]}

# creating a dataframe from a dictionary
dfs = pd.DataFrame(Pro)
#print(dfs)
dfs
# iterating over rows using iterrows() function
for i, j in dfs.iterrows():
    print(i, j)
    print()
# Try iteritems
for key, value in dfs.items():
    print(key, value)
    print()

# Home Work : Itertuples
# Iterating over Columns

# creating a list of dataframe columns
columns = list(dfs)

for i in columns:

    # printing the third element of the column
    print (dfs[i][1])
# Out:
# 0 Name     Ramesh
# BTech      Comp
# CGPA        9.0
# Name: 0, dtype: object
#
# 1 Name     Shreyas
# BTech        ETC
# CGPA         8.5
# Name: 1, dtype: object
#
# 2 Name     Rohit
# BTech     Mech
# CGPA       8.0
# Name: 2, dtype: object
#
# 3 Name     Rahul
# BTech    Civil
# CGPA      8.25
# Name: 3, dtype: object
#
# Name 0     Ramesh
# 1    Shreyas
# 2      Rohit
# 3      Rahul
# Name: Name, dtype: str
#
# BTech 0     Comp
# 1      ETC
# 2     Mech
# 3    Civil
# Name: BTech, dtype: str
#
# CGPA 0    9.00
# 1    8.50
# 2    8.00
# 3    8.25
# Name: CGPA, dtype: float64
#
# Shreyas
# ETC
# 8.5

# %%
dates = pd.date_range('20200101', periods=10)
print(dates)
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list('ABCD'))
df
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[us]', freq='D')
#                    A         B         C         D
# 2020-01-01 -0.616684 -0.039611  0.187230 -1.638798
# 2020-01-02  0.411291  1.112972 -0.469500  0.838346
# 2020-01-03  0.364574  0.105960  0.959453  1.035505
# 2020-01-04 -0.695418  1.457569 -1.242447 -1.643885
# 2020-01-05  0.554974  2.807185 -0.991315  0.641637
# 2020-01-06  0.664413 -0.769384  1.011274 -0.477760
# 2020-01-07  0.030968 -0.656089 -1.313214  1.160595
# 2020-01-08  0.100022 -0.403831 -0.325322 -0.354958
# 2020-01-09  1.557663  0.317389 -0.363533 -1.223337
# 2020-01-10  0.401942  1.221185 -0.058429 -1.010084

# %%
df.head(2)
# Out:
#                    A         B        C         D
# 2020-01-01 -0.616684 -0.039611  0.18723 -1.638798
# 2020-01-02  0.411291  1.112972 -0.46950  0.838346

# %%
df.head(2)
# Out:
#                    A         B        C         D
# 2020-01-01 -0.616684 -0.039611  0.18723 -1.638798
# 2020-01-02  0.411291  1.112972 -0.46950  0.838346

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[us]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %%
df.to_numpy() # Numpy array
# Out:
# array([[-0.61668416, -0.03961061,  0.18723026, -1.63879773],
#        [ 0.41129067,  1.11297151, -0.46950034,  0.83834583],
#        [ 0.36457436,  0.1059601 ,  0.95945258,  1.03550468],
#        [-0.69541793,  1.45756924, -1.24244744, -1.64388484],
#        [ 0.55497401,  2.80718512, -0.99131547,  0.64163693],
#        [ 0.66441332, -0.76938413,  1.01127364, -0.47776045],
#        [ 0.03096828, -0.65608914, -1.31321401,  1.16059521],
#        [ 0.10002249, -0.40383118, -0.32532171, -0.35495791],
#        [ 1.5576631 ,  0.31738861, -0.36353277, -1.22333746],
#        [ 0.40194164,  1.22118451, -0.05842918, -1.01008436]])

# %%
df.describe()  # Statistics of array
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.277375   0.515334  -0.260580  -0.267274
# std     0.645057   1.124382   0.817313   1.109480
# min    -0.695418  -0.769384  -1.313214  -1.643885
# 25%     0.048232  -0.312776  -0.860862  -1.170024
# 50%     0.383258   0.211674  -0.344427  -0.416359
# 75%     0.519053   1.194131   0.125815   0.789169
# max     1.557663   2.807185   1.011274   1.160595

# %%
df.T  # Transpose
# Out:
#    2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06  \
# A   -0.616684    0.411291    0.364574   -0.695418    0.554974    0.664413
# B   -0.039611    1.112972    0.105960    1.457569    2.807185   -0.769384
# C    0.187230   -0.469500    0.959453   -1.242447   -0.991315    1.011274
# D   -1.638798    0.838346    1.035505   -1.643885    0.641637   -0.477760
#
#    2020-01-07  2020-01-08  2020-01-09  2020-01-10
# A    0.030968    0.100022    1.557663    0.401942
# B   -0.656089   -0.403831    0.317389    1.221185
# C   -1.313214   -0.325322   -0.363533   -0.058429
# D    1.160595   -0.354958   -1.223337   -1.010084

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2020-01-01 -1.638798  0.187230 -0.039611 -0.616684
# 2020-01-02  0.838346 -0.469500  1.112972  0.411291
# 2020-01-03  1.035505  0.959453  0.105960  0.364574
# 2020-01-04 -1.643885 -1.242447  1.457569 -0.695418
# 2020-01-05  0.641637 -0.991315  2.807185  0.554974
# 2020-01-06 -0.477760  1.011274 -0.769384  0.664413
# 2020-01-07  1.160595 -1.313214 -0.656089  0.030968
# 2020-01-08 -0.354958 -0.325322 -0.403831  0.100022
# 2020-01-09 -1.223337 -0.363533  0.317389  1.557663
# 2020-01-10 -1.010084 -0.058429  1.221185  0.401942

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2020-01-01 -1.638798  0.187230 -0.039611 -0.616684
# 2020-01-02  0.838346 -0.469500  1.112972  0.411291
# 2020-01-03  1.035505  0.959453  0.105960  0.364574
# 2020-01-04 -1.643885 -1.242447  1.457569 -0.695418
# 2020-01-05  0.641637 -0.991315  2.807185  0.554974
# 2020-01-06 -0.477760  1.011274 -0.769384  0.664413
# 2020-01-07  1.160595 -1.313214 -0.656089  0.030968
# 2020-01-08 -0.354958 -0.325322 -0.403831  0.100022
# 2020-01-09 -1.223337 -0.363533  0.317389  1.557663
# 2020-01-10 -1.010084 -0.058429  1.221185  0.401942

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2020-01-06  0.664413 -0.769384  1.011274 -0.477760
# 2020-01-07  0.030968 -0.656089 -1.313214  1.160595
# 2020-01-08  0.100022 -0.403831 -0.325322 -0.354958
# 2020-01-01 -0.616684 -0.039611  0.187230 -1.638798
# 2020-01-03  0.364574  0.105960  0.959453  1.035505
# 2020-01-09  1.557663  0.317389 -0.363533 -1.223337
# 2020-01-02  0.411291  1.112972 -0.469500  0.838346
# 2020-01-10  0.401942  1.221185 -0.058429 -1.010084
# 2020-01-04 -0.695418  1.457569 -1.242447 -1.643885
# 2020-01-05  0.554974  2.807185 -0.991315  0.641637

# %%
df['A']
# Out:
# 2020-01-01   -0.616684
# 2020-01-02    0.411291
# 2020-01-03    0.364574
# 2020-01-04   -0.695418
# 2020-01-05    0.554974
# 2020-01-06    0.664413
# 2020-01-07    0.030968
# 2020-01-08    0.100022
# 2020-01-09    1.557663
# 2020-01-10    0.401942
# Freq: D, Name: A, dtype: float64

# %%
df[0:4]
# Out:
#                    A         B         C         D
# 2020-01-01 -0.616684 -0.039611  0.187230 -1.638798
# 2020-01-02  0.411291  1.112972 -0.469500  0.838346
# 2020-01-03  0.364574  0.105960  0.959453  1.035505
# 2020-01-04 -0.695418  1.457569 -1.242447 -1.643885

# %%
# Working with Locations
df.loc[dates[7]]
# Out:
# A    0.100022
# B   -0.403831
# C   -0.325322
# D   -0.354958
# Name: 2020-01-08 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'C']]
df.loc['2020-01-05':'2020-01-08', ['A', 'C']]
# Out:
#                    A         C
# 2020-01-05  0.554974 -0.991315
# 2020-01-06  0.664413  1.011274
# 2020-01-07  0.030968 -1.313214
# 2020-01-08  0.100022 -0.325322

# %%
# Data Location by selection of Integer Position
df.iloc[3]
df.iloc[3:5, 0:3]
# Out:
#                    A         B         C
# 2020-01-04 -0.695418  1.457569 -1.242447
# 2020-01-05  0.554974  2.807185 -0.991315

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2020-01-02  0.411291 -0.469500
# 2020-01-03  0.364574  0.959453
# 2020-01-05  0.554974 -0.991315

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2020-01-01 -0.039611  0.187230
# 2020-01-02  1.112972 -0.469500
# 2020-01-03  0.105960  0.959453
# 2020-01-04  1.457569 -1.242447
# 2020-01-05  2.807185 -0.991315
# 2020-01-06 -0.769384  1.011274
# 2020-01-07 -0.656089 -1.313214
# 2020-01-08 -0.403831 -0.325322
# 2020-01-09  0.317389 -0.363533
# 2020-01-10  1.221185 -0.058429

# %%
df.iloc[1, 1]   # df.iat can also be used
# Out:
# np.float64(1.112971512975508)

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2020-01-02  0.411291  1.112972 -0.469500  0.838346
# 2020-01-03  0.364574  0.105960  0.959453  1.035505
# 2020-01-05  0.554974  2.807185 -0.991315  0.641637
# 2020-01-06  0.664413 -0.769384  1.011274 -0.477760
# 2020-01-07  0.030968 -0.656089 -1.313214  1.160595
# 2020-01-08  0.100022 -0.403831 -0.325322 -0.354958
# 2020-01-09  1.557663  0.317389 -0.363533 -1.223337
# 2020-01-10  0.401942  1.221185 -0.058429 -1.010084

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2020-01-01       NaN       NaN  0.187230       NaN
# 2020-01-02  0.411291  1.112972       NaN  0.838346
# 2020-01-03  0.364574  0.105960  0.959453  1.035505
# 2020-01-04       NaN  1.457569       NaN       NaN
# 2020-01-05  0.554974  2.807185       NaN  0.641637
# 2020-01-06  0.664413       NaN  1.011274       NaN
# 2020-01-07  0.030968       NaN       NaN  1.160595
# 2020-01-08  0.100022       NaN       NaN       NaN
# 2020-01-09  1.557663  0.317389       NaN       NaN
# 2020-01-10  0.401942  1.221185       NaN       NaN

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three','one', 'two', 'three', 'four']
df2
# Out:
#                    A         B         C         D      E
# 2020-01-01 -0.616684 -0.039611  0.187230 -1.638798    one
# 2020-01-02  0.411291  1.112972 -0.469500  0.838346    one
# 2020-01-03  0.364574  0.105960  0.959453  1.035505    two
# 2020-01-04 -0.695418  1.457569 -1.242447 -1.643885  three
# 2020-01-05  0.554974  2.807185 -0.991315  0.641637   four
# 2020-01-06  0.664413 -0.769384  1.011274 -0.477760  three
# 2020-01-07  0.030968 -0.656089 -1.313214  1.160595    one
# 2020-01-08  0.100022 -0.403831 -0.325322 -0.354958    two
# 2020-01-09  1.557663  0.317389 -0.363533 -1.223337  three
# 2020-01-10  0.401942  1.221185 -0.058429 -1.010084   four

# %%
df.loc[:, 'D']*0
# Out:
# 2020-01-01   -0.0
# 2020-01-02    0.0
# 2020-01-03    0.0
# 2020-01-04   -0.0
# 2020-01-05    0.0
# 2020-01-06   -0.0
# 2020-01-07    0.0
# 2020-01-08   -0.0
# 2020-01-09   -0.0
# 2020-01-10   -0.0
# Freq: D, Name: D, dtype: float64

# %%
df.mean()
df.mean(1)    #  Mean on Other axis
# Out:
# C:\Users\sudar\AppData\Local\Temp\ipykernel_31124\671043220.py:2: Pandas4Warning: Starting with pandas version 4.0 all arguments of mean will be keyword-only.
#   df.mean(1)    #  Mean on Other axis
# 2020-01-01   -0.526966
# 2020-01-02    0.473277
# 2020-01-03    0.616373
# 2020-01-04   -0.531045
# 2020-01-05    0.753120
# 2020-01-06    0.107136
# 2020-01-07   -0.194435
# 2020-01-08   -0.246022
# 2020-01-09    0.072045
# 2020-01-10    0.138653
# Freq: D, dtype: float64

# %%
df.apply(np.sum)
# Out:
# A    2.773746
# B    5.153344
# C   -2.605804
# D   -2.672740
# dtype: float64

# %%
df.apply(lambda x: x.max() - x.min())  # Z Score and othe min max can also be calculated
# Out:
# A    2.253081
# B    3.576569
# C    2.324488
# D    2.804480
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.randn(10, 4))
df1
pd.concat([df,df1])
# Out:
#                             A         B         C         D         0  \
# 2020-01-01 00:00:00 -0.616684 -0.039611  0.187230 -1.638798       NaN
# 2020-01-02 00:00:00  0.411291  1.112972 -0.469500  0.838346       NaN
# 2020-01-03 00:00:00  0.364574  0.105960  0.959453  1.035505       NaN
# 2020-01-04 00:00:00 -0.695418  1.457569 -1.242447 -1.643885       NaN
# 2020-01-05 00:00:00  0.554974  2.807185 -0.991315  0.641637       NaN
# 2020-01-06 00:00:00  0.664413 -0.769384  1.011274 -0.477760       NaN
# 2020-01-07 00:00:00  0.030968 -0.656089 -1.313214  1.160595       NaN
# 2020-01-08 00:00:00  0.100022 -0.403831 -0.325322 -0.354958       NaN
# 2020-01-09 00:00:00  1.557663  0.317389 -0.363533 -1.223337       NaN
# 2020-01-10 00:00:00  0.401942  1.221185 -0.058429 -1.010084       NaN
# 0                         NaN       NaN       NaN       NaN  0.717494
# 1                         NaN       NaN       NaN       NaN -1.025373
# 2                         NaN       NaN       NaN       NaN  1.456811
# 3                         NaN       NaN       NaN       NaN -0.697735
# 4                         NaN       NaN       NaN       NaN  1.693478
# 5                         NaN       NaN       NaN       NaN  0.355119
# 6                         NaN       NaN       NaN       NaN -0.069589
# 7                         NaN       NaN       NaN       NaN  0.343187
# 8                         NaN       NaN       NaN       NaN  0.866786
# 9                         NaN       NaN       NaN       NaN -0.742183
#
#                             1         2         3
# 2020-01-01 00:00:00       NaN       NaN       NaN
# 2020-01-02 00:00:00       NaN       NaN       NaN
# 2020-01-03 00:00:00       NaN       NaN       NaN
# 2020-01-04 00:00:00       NaN       NaN       NaN
# 2020-01-05 00:00:00       NaN       NaN       NaN
# 2020-01-06 00:00:00       NaN       NaN       NaN
# 2020-01-07 00:00:00       NaN       NaN       NaN
# 2020-01-08 00:00:00       NaN       NaN       NaN
# 2020-01-09 00:00:00       NaN       NaN       NaN
# 2020-01-10 00:00:00       NaN       NaN       NaN
# 0                    0.902516  1.039221  0.017858
# 1                    0.004055  0.028599 -0.573990
# 2                    0.782091  2.385537 -0.685353
# 3                    0.744542  0.407323  0.631941
# 4                    0.019899 -0.839705 -0.898266
# 5                   -1.431784 -2.818419 -0.083517
# 6                   -0.376769 -0.858461  0.708733
# 7                    1.067640  0.490324 -1.432226
# 8                    0.875566 -0.342415  2.105904
# 9                    1.113832 -0.506141 -0.061077

# %%
s = df.iloc[3]

df = pd.concat([df, s.to_frame().T])
df
# Out:
#                    A         B         C         D
# 2020-01-01 -0.616684 -0.039611  0.187230 -1.638798
# 2020-01-02  0.411291  1.112972 -0.469500  0.838346
# 2020-01-03  0.364574  0.105960  0.959453  1.035505
# 2020-01-04 -0.695418  1.457569 -1.242447 -1.643885
# 2020-01-05  0.554974  2.807185 -0.991315  0.641637
# 2020-01-06  0.664413 -0.769384  1.011274 -0.477760
# 2020-01-07  0.030968 -0.656089 -1.313214  1.160595
# 2020-01-08  0.100022 -0.403831 -0.325322 -0.354958
# 2020-01-09  1.557663  0.317389 -0.363533 -1.223337
# 2020-01-10  0.401942  1.221185 -0.058429 -1.010084
# 2020-01-04 -0.695418  1.457569 -1.242447 -1.643885

# %%
rng = pd.date_range('2020-01-01', periods=100, freq='s')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts
# Out:
# 2020-01-01 00:00:00    491
# 2020-01-01 00:00:01    366
# 2020-01-01 00:00:02    335
# 2020-01-01 00:00:03    327
# 2020-01-01 00:00:04    223
#                       ...
# 2020-01-01 00:01:35    274
# 2020-01-01 00:01:36    237
# 2020-01-01 00:01:37    281
# 2020-01-01 00:01:38     45
# 2020-01-01 00:01:39     12
# Freq: s, Length: 100, dtype: int32

# %%
import matplotlib.pyplot as plt
s.plot()
plt.show()

# %%
df.plot()
# Out:
# <Axes: >

# %%
dfs.to_csv(r"C:\Users\sudar\Downloads\test.csv", index=False)

# %%
df = pd.read_csv("test.csv")
display(df.head())
# Out:
#       Name  BTech  CGPA
# 0   Ramesh   Comp  9.00
# 1  Shreyas    ETC  8.50
# 2    Rohit   Mech  8.00
# 3    Rahul  Civil  8.25

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\sudar\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\sudar\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dfs.to_excel(r"C:\Users\sudar\Downloads\pand.xlsx", index=False)

# %%
dfs.to_excel('pand.xlsx')

# %%
dfs.to_hdf(r"C:\Users\sudar\Downloads\dff.h5", key="data")

# %%
df = pd.read_hdf(r"C:\Users\sudar\Downloads\dff.h5", key="data")
print(df.head())
# Out:
#       Name  BTech  CGPA
# 0   Ramesh   Comp  9.00
# 1  Shreyas    ETC  8.50
# 2    Rohit   Mech  8.00
# 3    Rahul  Civil  8.25
