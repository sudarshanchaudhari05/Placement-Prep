# %% [markdown]
# Data Handling and Analysis with Pandas

# %% [markdown]
# pandas is Python package
#
# Provides fast, flexible, and expressive data structures designed to make working with relational or labeled data.
#
# Open source data analysis and manipulation tool.
#
# Its is suited for
#
# Tabular data with heterogeneously-typed columns, as in an Excel spreadsheet
# Ordered and unordered (not necessarily fixed-frequency) time series data.
# Arbitrary matrix data (homogeneously typed or heterogeneous) with row and column labels
# Any other form of observational / statistical data sets.

# %% [markdown]
# Features
#
# • Easy handling of missing data (represented as NaN) in floating point as well as non-floating point data.
#
# • Size mutability: columns can be inserted and deleted from DataFrame and higher dimensional objects.
#
# • Automatic and explicit data alignment.
#
# • Powerful, flexible group by functionality to perform split-apply-combine operations on data sets, for both ag- gregating and transforming data.
#
# • Make it easy to convert ragged, differently-indexed data in other Python and NumPy data structures into DataFrame objects.
#
# • Intelligent label-based slicing, fancy indexing, and subsetting of large data sets.
#
# • Intuitive merging and joining data sets.
#
# • Flexible reshaping and pivoting of data sets.
#
# • Hierarchical labeling of axes (possible to have multiple labels per tick).
#
# • Robust IO tools for loading data from flat files (CSV and delimited), Excel files, databases, and saving / loading data from the ultrafast HDF5 format.
#
# • Time series-specific functionality: date range generation and frequency conversion, moving window statistics, moving window linear regressions, date shifting and lagging, etc.
#
# Pandas handle Series (1D) and DataFrame (2D) datastructures

# %%
import pandas as pd
import numpy as np
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
s.isnull()
print(s)
s.fillna(0)
print(s)
s.interpolate()
print(s)
s.dropna()
print(s)
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
n=pd.Series(['VIIT','VIT','VCACS','VU','VIM'])
n
# Out:
# 0     VIIT
# 1      VIT
# 2    VCACS
# 3       VU
# 4      VIM
# dtype: str

# %%
inst={'Name':['VIIT','VIT','VCACS','VU','VIM'],
      'Estd' :[2002,1984,2008,2017,2000]}
df=pd.DataFrame(inst)
#print(df)
df
# Out:
#     Name  Estd
# 0   VIIT  2002
# 1    VIT  1984
# 2  VCACS  2008
# 3     VU  2017
# 4    VIM  2000

# %%
i=pd.Series([2002,1984,2008,2017,2000])
inst={'Name':n,
      'Estd' :i}
ins=pd.DataFrame(inst)
ins
print(ins['Name'])
print(ins)
ins.index
# Out:
# 0     VIIT
# 1      VIT
# 2    VCACS
# 3       VU
# 4      VIM
# Name: Name, dtype: str
#     Name  Estd
# 0   VIIT  2002
# 1    VIT  1984
# 2  VCACS  2008
# 3     VU  2017
# 4    VIM  2000
# RangeIndex(start=0, stop=5, step=1)

# %%
dict = {'First Score':[100, 90, np.nan, 95],
        'Second Score': [30, np.nan, 45, 56],
        'Third Score':[52, 40, 80, 98],
        'Fourth Score':[np.nan, np.nan, np.nan, 65]}

# creating a dataframe from dictionary
df = pd.DataFrame(dict)
df
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 0        100.0          30.0           52           NaN
# 1         90.0           NaN           40           NaN
# 2          NaN          45.0           80           NaN
# 3         95.0          56.0           98          65.0

# %%
# using dropna() function
df.dropna()
# Out:
#    First Score  Second Score  Third Score  Fourth Score
# 3         95.0          56.0           98          65.0

# %%
import pandas as pd

# dictionary of lists
Pro = {'Name':['Ramesh', 'Shreyas', 'Rohit', 'Rahul'],
        'BTech': ['Comp', 'ETC', 'Mech', 'Civil'],
        'CGPA':[9, 8.5, 8, 8.25]}

# creating a dataframe from a dictionary
dfs = pd.DataFrame(Pro)
#print(dfs)
dfs
# iterating over rows using iterrows() function
for i, j in dfs.iterrows():
    print(i, j)
    print()
# Try iteritems
for key, value in dfs.items():
    print(key, value)
    print()

# Home Work : Itertuples
# Iterating over Columns

# creating a list of dataframe columns
columns = list(dfs)

for i in columns:

    # printing the third element of the column
    print (dfs[i][1])
# Out:
# 0 Name     Ramesh
# BTech      Comp
# CGPA        9.0
# Name: 0, dtype: object
#
# 1 Name     Shreyas
# BTech        ETC
# CGPA         8.5
# Name: 1, dtype: object
#
# 2 Name     Rohit
# BTech     Mech
# CGPA       8.0
# Name: 2, dtype: object
#
# 3 Name     Rahul
# BTech    Civil
# CGPA      8.25
# Name: 3, dtype: object
#
# Name 0     Ramesh
# 1    Shreyas
# 2      Rohit
# 3      Rahul
# Name: Name, dtype: str
#
# BTech 0     Comp
# 1      ETC
# 2     Mech
# 3    Civil
# Name: BTech, dtype: str
#
# CGPA 0    9.00
# 1    8.50
# 2    8.00
# 3    8.25
# Name: CGPA, dtype: float64
#
# Shreyas
# ETC
# 8.5

# %%
dates = pd.date_range('20200101', periods=10)
print(dates)
df = pd.DataFrame(np.random.randn(10, 4), index=dates, columns=list('ABCD'))
df
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[us]', freq='D')
#                    A         B         C         D
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749
# 2020-01-02 -1.449722  0.157870 -1.190539  2.089293
# 2020-01-03 -0.109097  1.166627 -0.909667 -0.348278
# 2020-01-04  1.202202  0.145879 -1.283864 -1.220705
# 2020-01-05  0.714514  0.412351 -0.449641 -0.518107
# 2020-01-06 -1.824921 -0.918677 -0.005627 -0.666188
# 2020-01-07  1.419220 -0.554967  0.943421 -0.866501
# 2020-01-08 -2.206962 -0.949421  0.686472 -2.013308
# 2020-01-09  0.855045 -0.661024  0.562493  0.072194
# 2020-01-10  0.692891 -0.226927 -0.209780 -0.089890

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749
# 2020-01-02 -1.449722  0.157870 -1.190539  2.089293

# %%
df.head(2)
# Out:
#                    A         B         C         D
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749
# 2020-01-02 -1.449722  0.157870 -1.190539  2.089293

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[us]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='str')

# %%
df.to_numpy() # Numpy array
# Out:
# array([[ 0.20211249, -0.49775773, -0.62618571,  0.93374934],
#        [-1.44972164,  0.15786991, -1.19053914,  2.08929341],
#        [-0.10909669,  1.16662653, -0.90966714, -0.3482779 ],
#        [ 1.20220152,  0.14587908, -1.28386431, -1.22070484],
#        [ 0.71451391,  0.41235053, -0.44964062, -0.51810725],
#        [-1.82492138, -0.91867733, -0.00562696, -0.66618797],
#        [ 1.41922018, -0.55496736,  0.94342051, -0.86650072],
#        [-2.20696164, -0.94942085,  0.68647175, -2.01330816],
#        [ 0.85504547, -0.6610238 ,  0.56249266,  0.07219444],
#        [ 0.69289085, -0.22692686, -0.20977961, -0.08988998]])

# %%
df.describe()  # Statistics of array
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean   -0.050472  -0.192605  -0.248292  -0.262774
# std     1.312808   0.666321   0.788297   1.139577
# min    -2.206962  -0.949421  -1.283864  -2.013308
# 25%    -1.114565  -0.634510  -0.838797  -0.816423
# 50%     0.447502  -0.362342  -0.329710  -0.433193
# 75%     0.819913   0.154872   0.420463   0.031673
# max     1.419220   1.166627   0.943421   2.089293

# %%
df.T  # Transpose
# Out:
#    2020-01-01  2020-01-02  2020-01-03  2020-01-04  2020-01-05  2020-01-06  \
# A    0.202112   -1.449722   -0.109097    1.202202    0.714514   -1.824921
# B   -0.497758    0.157870    1.166627    0.145879    0.412351   -0.918677
# C   -0.626186   -1.190539   -0.909667   -1.283864   -0.449641   -0.005627
# D    0.933749    2.089293   -0.348278   -1.220705   -0.518107   -0.666188
#
#    2020-01-07  2020-01-08  2020-01-09  2020-01-10
# A    1.419220   -2.206962    0.855045    0.692891
# B   -0.554967   -0.949421   -0.661024   -0.226927
# C    0.943421    0.686472    0.562493   -0.209780
# D   -0.866501   -2.013308    0.072194   -0.089890

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2020-01-01  0.933749 -0.626186 -0.497758  0.202112
# 2020-01-02  2.089293 -1.190539  0.157870 -1.449722
# 2020-01-03 -0.348278 -0.909667  1.166627 -0.109097
# 2020-01-04 -1.220705 -1.283864  0.145879  1.202202
# 2020-01-05 -0.518107 -0.449641  0.412351  0.714514
# 2020-01-06 -0.666188 -0.005627 -0.918677 -1.824921
# 2020-01-07 -0.866501  0.943421 -0.554967  1.419220
# 2020-01-08 -2.013308  0.686472 -0.949421 -2.206962
# 2020-01-09  0.072194  0.562493 -0.661024  0.855045
# 2020-01-10 -0.089890 -0.209780 -0.226927  0.692891

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    D         C         B         A
# 2020-01-01  0.933749 -0.626186 -0.497758  0.202112
# 2020-01-02  2.089293 -1.190539  0.157870 -1.449722
# 2020-01-03 -0.348278 -0.909667  1.166627 -0.109097
# 2020-01-04 -1.220705 -1.283864  0.145879  1.202202
# 2020-01-05 -0.518107 -0.449641  0.412351  0.714514
# 2020-01-06 -0.666188 -0.005627 -0.918677 -1.824921
# 2020-01-07 -0.866501  0.943421 -0.554967  1.419220
# 2020-01-08 -2.013308  0.686472 -0.949421 -2.206962
# 2020-01-09  0.072194  0.562493 -0.661024  0.855045
# 2020-01-10 -0.089890 -0.209780 -0.226927  0.692891

# %%
df.sort_values(by='B')
# Out:
#                    A         B         C         D
# 2020-01-08 -2.206962 -0.949421  0.686472 -2.013308
# 2020-01-06 -1.824921 -0.918677 -0.005627 -0.666188
# 2020-01-09  0.855045 -0.661024  0.562493  0.072194
# 2020-01-07  1.419220 -0.554967  0.943421 -0.866501
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749
# 2020-01-10  0.692891 -0.226927 -0.209780 -0.089890
# 2020-01-04  1.202202  0.145879 -1.283864 -1.220705
# 2020-01-02 -1.449722  0.157870 -1.190539  2.089293
# 2020-01-05  0.714514  0.412351 -0.449641 -0.518107
# 2020-01-03 -0.109097  1.166627 -0.909667 -0.348278

# %%
df['A']
# Out:
# 2020-01-01    0.202112
# 2020-01-02   -1.449722
# 2020-01-03   -0.109097
# 2020-01-04    1.202202
# 2020-01-05    0.714514
# 2020-01-06   -1.824921
# 2020-01-07    1.419220
# 2020-01-08   -2.206962
# 2020-01-09    0.855045
# 2020-01-10    0.692891
# Freq: D, Name: A, dtype: float64

# %%
df[0:4]
# Out:
#                    A         B         C         D
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749
# 2020-01-02 -1.449722  0.157870 -1.190539  2.089293
# 2020-01-03 -0.109097  1.166627 -0.909667 -0.348278
# 2020-01-04  1.202202  0.145879 -1.283864 -1.220705

# %%
# Working with Locations
df.loc[dates[7]]
# Out:
# A   -2.206962
# B   -0.949421
# C    0.686472
# D   -2.013308
# Name: 2020-01-08 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'C']]
df.loc['2020-01-05':'2020-01-08', ['A', 'C']]
# Out:
#                    A         C
# 2020-01-05  0.714514 -0.449641
# 2020-01-06 -1.824921 -0.005627
# 2020-01-07  1.419220  0.943421
# 2020-01-08 -2.206962  0.686472

# %%
# Data Location by selection of Integer Position
df.iloc[3]
df.iloc[3:5, 0:3]
# Out:
#                    A         B         C
# 2020-01-04  1.202202  0.145879 -1.283864
# 2020-01-05  0.714514  0.412351 -0.449641

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2020-01-02 -1.449722 -1.190539
# 2020-01-03 -0.109097 -0.909667
# 2020-01-05  0.714514 -0.449641

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2020-01-01 -0.497758 -0.626186
# 2020-01-02  0.157870 -1.190539
# 2020-01-03  1.166627 -0.909667
# 2020-01-04  0.145879 -1.283864
# 2020-01-05  0.412351 -0.449641
# 2020-01-06 -0.918677 -0.005627
# 2020-01-07 -0.554967  0.943421
# 2020-01-08 -0.949421  0.686472
# 2020-01-09 -0.661024  0.562493
# 2020-01-10 -0.226927 -0.209780

# %%
df.iloc[1, 1]   # df.iat can also be used
# Out:
# np.float64(0.15786991493765118)

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749
# 2020-01-04  1.202202  0.145879 -1.283864 -1.220705
# 2020-01-05  0.714514  0.412351 -0.449641 -0.518107
# 2020-01-07  1.419220 -0.554967  0.943421 -0.866501
# 2020-01-09  0.855045 -0.661024  0.562493  0.072194
# 2020-01-10  0.692891 -0.226927 -0.209780 -0.089890

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2020-01-01  0.202112       NaN       NaN  0.933749
# 2020-01-02       NaN  0.157870       NaN  2.089293
# 2020-01-03       NaN  1.166627       NaN       NaN
# 2020-01-04  1.202202  0.145879       NaN       NaN
# 2020-01-05  0.714514  0.412351       NaN       NaN
# 2020-01-06       NaN       NaN       NaN       NaN
# 2020-01-07  1.419220       NaN  0.943421       NaN
# 2020-01-08       NaN       NaN  0.686472       NaN
# 2020-01-09  0.855045       NaN  0.562493  0.072194
# 2020-01-10  0.692891       NaN       NaN       NaN

# %%
df2 = df.copy()
df2['E'] = ['one', 'one', 'two', 'three', 'four', 'three','one', 'two', 'three', 'four']
df2
# Out:
#                    A         B         C         D      E
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749    one
# 2020-01-02 -1.449722  0.157870 -1.190539  2.089293    one
# 2020-01-03 -0.109097  1.166627 -0.909667 -0.348278    two
# 2020-01-04  1.202202  0.145879 -1.283864 -1.220705  three
# 2020-01-05  0.714514  0.412351 -0.449641 -0.518107   four
# 2020-01-06 -1.824921 -0.918677 -0.005627 -0.666188  three
# 2020-01-07  1.419220 -0.554967  0.943421 -0.866501    one
# 2020-01-08 -2.206962 -0.949421  0.686472 -2.013308    two
# 2020-01-09  0.855045 -0.661024  0.562493  0.072194  three
# 2020-01-10  0.692891 -0.226927 -0.209780 -0.089890   four

# %%
df.loc[:, 'D']*0
# Out:
# 2020-01-01    0.0
# 2020-01-02    0.0
# 2020-01-03   -0.0
# 2020-01-04   -0.0
# 2020-01-05   -0.0
# 2020-01-06   -0.0
# 2020-01-07   -0.0
# 2020-01-08   -0.0
# 2020-01-09    0.0
# 2020-01-10   -0.0
# Freq: D, Name: D, dtype: float64

# %%
df.mean()
df.mean(1)    #  Mean on Other axis
# Out:
# C:\Users\sudar\AppData\Local\Temp\ipykernel_25716\671043220.py:2: Pandas4Warning: Starting with pandas version 4.0 all arguments of mean will be keyword-only.
#   df.mean(1)    #  Mean on Other axis
# 2020-01-01    0.002980
# 2020-01-02   -0.098274
# 2020-01-03   -0.050104
# 2020-01-04   -0.289122
# 2020-01-05    0.039779
# 2020-01-06   -0.853853
# 2020-01-07    0.235293
# 2020-01-08   -1.120805
# 2020-01-09    0.207177
# 2020-01-10    0.041574
# Freq: D, dtype: float64

# %%
df.apply(np.sum)
# Out:
# A   -0.504717
# B   -1.926048
# C   -2.482919
# D   -2.627740
# dtype: float64

# %%
df.apply(lambda x: x.max() - x.min())  # Z Score and othe min max can also be calculated
# Out:
# A    3.626182
# B    2.116047
# C    2.227285
# D    4.102602
# dtype: float64

# %%
df1 = pd.DataFrame(np.random.randn(10, 4))
df1
pd.concat([df,df1])
# Out:
#                             A         B         C         D         0  \
# 2020-01-01 00:00:00  0.202112 -0.497758 -0.626186  0.933749       NaN
# 2020-01-02 00:00:00 -1.449722  0.157870 -1.190539  2.089293       NaN
# 2020-01-03 00:00:00 -0.109097  1.166627 -0.909667 -0.348278       NaN
# 2020-01-04 00:00:00  1.202202  0.145879 -1.283864 -1.220705       NaN
# 2020-01-05 00:00:00  0.714514  0.412351 -0.449641 -0.518107       NaN
# 2020-01-06 00:00:00 -1.824921 -0.918677 -0.005627 -0.666188       NaN
# 2020-01-07 00:00:00  1.419220 -0.554967  0.943421 -0.866501       NaN
# 2020-01-08 00:00:00 -2.206962 -0.949421  0.686472 -2.013308       NaN
# 2020-01-09 00:00:00  0.855045 -0.661024  0.562493  0.072194       NaN
# 2020-01-10 00:00:00  0.692891 -0.226927 -0.209780 -0.089890       NaN
# 0                         NaN       NaN       NaN       NaN  0.646918
# 1                         NaN       NaN       NaN       NaN  2.533228
# ...

# %%
s = df.iloc[3]

df = pd.concat([df, s.to_frame().T])
df
# Out:
#                    A         B         C         D
# 2020-01-01  0.202112 -0.497758 -0.626186  0.933749
# 2020-01-02 -1.449722  0.157870 -1.190539  2.089293
# 2020-01-03 -0.109097  1.166627 -0.909667 -0.348278
# 2020-01-04  1.202202  0.145879 -1.283864 -1.220705
# 2020-01-05  0.714514  0.412351 -0.449641 -0.518107
# 2020-01-06 -1.824921 -0.918677 -0.005627 -0.666188
# 2020-01-07  1.419220 -0.554967  0.943421 -0.866501
# 2020-01-08 -2.206962 -0.949421  0.686472 -2.013308
# 2020-01-09  0.855045 -0.661024  0.562493  0.072194
# 2020-01-10  0.692891 -0.226927 -0.209780 -0.089890
# 2020-01-04  1.202202  0.145879 -1.283864 -1.220705

# %%
rng = pd.date_range('2020-01-01', periods=100, freq='s')
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)
ts
# Out:
# 2020-01-01 00:00:00    104
# 2020-01-01 00:00:01     63
# 2020-01-01 00:00:02    146
# 2020-01-01 00:00:03     83
# 2020-01-01 00:00:04    313
#                       ...
# 2020-01-01 00:01:35    207
# 2020-01-01 00:01:36    440
# 2020-01-01 00:01:37    259
# 2020-01-01 00:01:38    407
# 2020-01-01 00:01:39    386
# Freq: s, Length: 100, dtype: int32

# %%
import matplotlib.pyplot as plt
s.plot()
plt.show()

# %%
df.plot()
# Out:
# <Axes: >

# %%
dfs.to_csv(r"C:\Users\sudar\Downloads\test.csv", index=False)

# %%
df = pd.read_csv("test.csv")
display(df.head())
# Out:
#       Name  BTech  CGPA
# 0   Ramesh   Comp  9.00
# 1  Shreyas    ETC  8.50
# 2    Rohit   Mech  8.00
# 3    Rahul  Civil  8.25

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
dfs.to_excel(r"C:\Users\sudar\Downloads\pand.xlsx", index=False)

# %%
dfs.to_excel('pand.xlsx')

# %%
dfs.to_hdf(r"C:\Users\sudar\Downloads\dff.h5", key="data")

# %%
df = pd.read_hdf(r"C:\Users\sudar\Downloads\dff.h5", key="data")
print(df.head())
# Out:
#       Name  BTech  CGPA
# 0   Ramesh   Comp  9.00
# 1  Shreyas    ETC  8.50
# 2    Rohit   Mech  8.00
# 3    Rahul  Civil  8.25
